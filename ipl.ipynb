# %% [markdown]
# # IPL EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Data_Science_CSVs\deliveries.csv")
df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
df.shape
# Out:
# (260920, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
df.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %%
df["match_id"].nunique()
# Out:
# 1095

# %%
df["total_runs"].sum()
# Out:
# 347756

# %%
top_batsmen = (
    df.groupby("batter")["batsman_runs"].sum().sort_values(ascending=False).head(10)
    )
top_batsmen
# Out:
# batter
# V Kohli           8014
# S Dhawan          6769
# RG Sharma         6630
# DA Warner         6567
# SK Raina          5536
# MS Dhoni          5243
# AB de Villiers    5181
# CH Gayle          4997
# RV Uthappa        4954
# KD Karthik        4843
# Name: batsman_runs, dtype: int64

# %%
top_batsmen.plot(kind='bar')
plt.title("Top 10 IPL Run Scorers")
plt.xlabel("Batsman")
plt.ylabel("Runs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_bowlers = (
    df[df["is_wicket"] == 1].groupby('bowler')['is_wicket']
    .count().sort_values(ascending=False).head(10)
    )
top_bowlers
# Out:
# bowler
# YS Chahal     213
# DJ Bravo      207
# PP Chawla     201
# SP Narine     200
# R Ashwin      198
# B Kumar       195
# SL Malinga    188
# A Mishra      183
# JJ Bumrah     182
# RA Jadeja     169
# Name: is_wicket, dtype: int64

# %%
top_bowlers.plot(kind='bar')
plt.title("Top 10 IPL Wicket Takers")
plt.xlabel("Bowler")
plt.ylabel("Wickets")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Strike Rate of BatsMen
batsman_runs = (
    df.groupby('batter')["batsman_runs"].sum().sort_values(ascending=False)
)
batsman_runs
# Out:
# batter
# V Kohli         8014
# S Dhawan        6769
# RG Sharma       6630
# DA Warner       6567
# SK Raina        5536
#                 ...
# S Ladda            0
# S Lamichhane       0
# Abdur Razzak       0
# SS Cottrell        0
# KM Asif            0
# Name: batsman_runs, Length: 673, dtype: int64

# %%
balls = df.groupby('batter')['ball'].count().sort_values(ascending=False)
balls
# Out:
# batter
# V Kohli          6236
# S Dhawan         5483
# RG Sharma        5183
# DA Warner        4849
# SK Raina         4177
#                  ...
# YA Abdulla          1
# DP Vijaykumar       1
# Y Prithvi Raj       1
# S Kaushik           1
# NJ Rimmington       1
# Name: ball, Length: 673, dtype: int64

# %%
strike_rate = (batsman_runs/balls)*100
top10_Striker = strike_rate.sort_values(ascending=False).head(10)

# %%
top10_Striker.plot(kind='bar')
plt.title("Strike Rate of Top 10 BatsMen")
plt.xlabel("Batter")
plt.ylabel("Strike Rate")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
team_runs = (
    df.groupby("batting_team")["total_runs"]
    .sum()
    .sort_values(ascending=False)
).head(10)
team_runs.plot(kind='bar')
plt.title("Total Runs by IPL Teams")
plt.xlabel("Team")
plt.ylabel("Team Runs")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Key Insights

# %% [markdown]
# * **Mumbai Indians** have scored the highest total runs in IPL history, indicating strong and consistent batting performance across seasons.
# * **Luke Wood** shows the highest strike rate, followed by **Billy Stanlake**, highlighting highly aggressive scoring rates in limited opportunities.
# * **Yuzvendra Chahal, D.J. Bravo, P.P. Chawla, Sunil Narine, and Ravichandran Ashwin** emerge as the **top five wicket-taking bowlers**, reflecting their long-term impact in IPL bowling performance.
# * **Virat Kohli, Shikhar Dhawan, Rohit Sharma, David Warner, and Suresh Raina** are the **leading run scorers in IPL history**, demonstrating consistency and longevity at the top level of T20 cricket.
#
# ### Overall Conclusion
#
# The analysis highlights that **team success is strongly driven by consistent high-run scorers and experienced wicket-taking bowlers**, while strike rate identifies explosive players who can change match momentum quickly.
